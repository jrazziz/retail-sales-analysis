# %% [markdown]
# # 1. Data Cleaning

# %% [markdown]
# ## 1.1 Import and Data

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('Superstore.xls')
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03 2023-01-07  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 3       4  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-01-05 2023-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %% [markdown]
# ## 1.2 Initial Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
# ...

# %% [markdown]
# ## 1.3 Dataset Shape

# %%
df.shape
# Out:
# (10194, 21)

# %% [markdown]
# ## Checking Null Values

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %% [markdown]
# ## Checking duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Check Data types

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State/Province            object
# Postal Code               object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %% [markdown]
# ##  Logical Error Checks

# %%
(df['Sales'] < 0).sum()
# Out:
# 0

# %%
(df['Quantity'] < 0).sum()
# Out:
# 0

# %%
(df['Discount'] > 1).sum()
# Out:
# 0

# %%
(df['Ship Date'] < df['Order Date']).sum()
# Out:
# 0

# %%
df['Discount'].describe()
# Out:
# count    10194.000000
# mean         0.155385
# std          0.206249
# min          0.000000
# 25%          0.000000
# 50%          0.200000
# 75%          0.200000
# max          0.800000
# Name: Discount, dtype: float64

# %%
df['Profit'].describe()
# Out:
# count    10194.000000
# mean        28.673417
# std        232.465115
# min      -6599.978000
# 25%          1.760800
# 50%          8.690000
# 75%         29.297925
# max       8399.976000
# Name: Profit, dtype: float64

# %% [markdown]
# ## Worst losses

# %%
df.nsmallest(10, 'Profit')[['Order ID','Product Name','Category','Sales', 'Discount', 'Profit']]
# Out:
#             Order ID                                       Product Name  \
# 6398  US-2025-108196          Cubify CubeX 3D Printer Double Head Print
# 9318  US-2026-168116          Cubify CubeX 3D Printer Triple Head Print
# 821   US-2023-169019          GBC DocuBind P400 Electric Binding System
# 7441  US-2026-134845          Lexmark MX611dhe Monochrome Laser Printer
# 9845  US-2026-122714               Ibico EPK-21 Electric Binding System
# 4037  US-2024-147830          Cubify CubeX 3D Printer Double Head Print
# 9557  US-2026-131254  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 2108  US-2024-116638  Chromcraft Bull-Nose Wood Oval Conference Tabl...
# 4570  US-2025-130946          GBC DocuBind P400 Electric Binding System
# 226   US-2023-145317  Cisco TelePresence System EX90 Videoconferenci...
#
#              Category      Sales  Discount     Profit
# 6398       Technology   4499.985       0.7 -6599.9780
# 9318       Technology   7999.980       0.5 -3839.9904
# ...

# %% [markdown]
# ## Best profits

# %%
df.nlargest(10, 'Profit')[['Order ID','Product Name','Category','Sales', 'Discount', 'Profit']]
# Out:
#             Order ID                                       Product Name  \
# 5894  US-2025-118689              Canon imageCLASS 2200 Advanced Copier
# 7255  US-2026-140151              Canon imageCLASS 2200 Advanced Copier
# 9517  US-2026-166709              Canon imageCLASS 2200 Advanced Copier
# 6674  US-2025-117121   GBC Ibimaster 500 Manual ProClick Binding System
# 1203  US-2023-116904               Ibico EPK-21 Electric Binding System
# 9171  US-2026-127180              Canon imageCLASS 2200 Advanced Copier
# 2242  US-2024-145352  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 4282  US-2025-158841  HP Designjet T520 Inkjet Large Format Printer ...
# 5907  US-2025-140158               Hewlett Packard LaserJet 3310 Copier
# 6882  US-2026-138289          GBC DocuBind P400 Electric Binding System
#
#              Category      Sales  Discount     Profit
# 5894       Technology  17499.950       0.0  8399.9760
# 7255       Technology  13999.960       0.0  6719.9808
# ...

# %% [markdown]
# ## High discount orders — are they profitable?

# %%
df[df['Discount'] >= 0.5]['Profit'].describe()
# Out:
# count     940.000000
# mean     -103.762359
# std       379.791428
# min     -6599.978000
# 25%       -48.392000
# 50%       -13.431500
# 75%        -4.958700
# max        -0.596400
# Name: Profit, dtype: float64

# %% [markdown]
# ## Create new columns
# ### 1-Shipping Days
# ### 2-Profit Margin
# ### 3-Year, Month, Year-Month

# %%
df['Shipping_Days'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
df['Profit_Margin'] = df['Profit'] / df['Sales']

# %%
df['Year'] = df['Order Date'].dt.year

# %%
df['Month'] = df['Order Date'].dt.month

# %%
df['Year_Month'] = df['Order Date'].dt.to_period('M').astype(str)

# %%
df.to_csv('clean_sales.csv', index=False)

# %%
df.to_csv('C:/Users/aziza/Downloads/clean_sales.csv', index=False)
